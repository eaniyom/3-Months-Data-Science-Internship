# %% [markdown]
# ### Instructions
#
# This hands on exercise is expected to cover the topics treated on statistics and mathematics (probability) divided into two sections, each of the sections have 20 questions
#
#
# You are required to adhere to the instructions below;
#
# 1. This hands-on session is to completed and submitted within the hours of the training time interval.
# 2. Your functions and variables names are to be unique as you may be penalized for plagiarism (i.e. Your codes has to be unique)
# 3. The use of defined functions are allowed
# 4. You must add comments to your codes to validate authenticity of your codes.
# 5. You are free to consult any source or resource (But try to give credits, like links, blog names or docs, etc.)
# 6. You must submit before leaving the venue of the training today.
# 7. I may not be available as a source... lol

# %% [markdown]
# ### Section A - Statistics

# %% [markdown]
# ##### Question 1
# The police service in the small city of Oakford mounted an intensive photo radar campaign to reduce drivers’ speeds in school zones. The speed limit in Oakford’s school zones is 30 kph. Past records (from before the radar campaign began) indicate that the average recorded speed in Oakford school zones was 34 kph, and that the majority of drivers exceeded this average recorded speed. Having included all the school zones in the city in their photo radar campaign, the Oakford police service recorded the speeds (in kph) of a random sample of 20 drivers from various school zones in Oakford, as follows. !![image-2.png](attachment:image-2.png)
# Based on the 20 data values above:
# * Compute the mean speed.
# * Compute the median speed.
# * Determine the modal speed.
# * Compute the standard deviation of the 20 speed values.
# * Of the drivers recorded, 25% showed speeds on or below what rate of speed (in kph)?
# * Based on a comparison of the mean and media speeds computed in a and b above, comment on the skewness of the distribution of the 20 recorded speeds.
# * Construct a frequency distribution of the data, using equal class intervals of 5 (i.e., class width = 5). Make your first class 20 to 24. For each class in your distribution, show the midpoint, the frequency, the relative frequency (in percent), and the less than cumulative frequency.

# %% [markdown]
# ##### Question 2
# A sample of 100 graduates who completed a 6-month security guard training program reported the following monthly starting salaries (in security guard related employment).
# ![image.png](attachment:image.png)
# * Compute the (approximate) mean monthly starting salary.
# * Compute the (approximate) standard deviation of the monthly starting salaries.
# * Plot a relative frequency histogram, using a percentage scale on the Y-axis. Based on the plot, determine if the distribution of the salaries is positively or negatively skewed. What does the skewness reveal, in terms of the distribution of starting salaries?

# %% [markdown]
# ##### Question 3
# InfoMart is a research firm that collects and analyzes information for business firms, government agencies, non-profit organizations, and consumer clients. InfoMart has just completed a report comparing the demographic features of two cities that have similar size populations. In this question, you will examine some of the summary statistics that InfoMart computed with respect to two demographic variables: monthly household income, and age of the homeowner. These summary statistics are presented in the table below. (Homeowner age for Mountainview is not shown in the table, as it is not required to complete this problem.)
# ![image.png](attachment:image.png)
# * Determine the median monthly household income for each city as shown in the table above.
# * In Rivercity, which variable, income or age, exhibits the greater degree of relative variability? Compute the appropriate statistics.
# * In Mountainview, within what range of monthly household income does the middle 50% of households fall?
# * Compute the variance for the age variable for Rivercity.
# * In Rivercity, 75% of the households surveyed exceed what age?
# * In Mountainview, 75% of the households surveyed earned less than what monthly income?

# %% [markdown]
# ##### Question 4
# Joe Smith, a student at Metro University, completed the courses Biology 101, Psychology 210, Chemistry 250, and English 200 in the fall semester of 2015. He received the grades transcript below.
# ![image.png](attachment:image.png)
# * Compute Joe Smith’s overall average grade (often called grade point average) for the fall semester.

# %% [markdown]
# ### Section B - Basic Mathematics (Probability)

# %% [markdown]
# #### Question 1
# The table below summarizes the results of a survey that asked 5000 faculty and students at a Canadianuniversity whether they support a proposed ban on the sale of junk food (chips, pop, candy, and chocolate bars) on campus.
# ![image.png](attachment:image.png)
# If one of the 5000 individuals surveyed is selected at random:
# * Find the probability that the individual selected opposes the proposed ban.
# * Find the probability that the individual selected is a student.
# * Find the probability that the individual selected is a student and opposes the proposed ban.
# * Find the probability that the individual selected is faculty or supports the proposed ban.
# * Find the probability that the individual selected is a student given that the individual selected opposes the proposed ban.
# * Find the probability that the individual selected supports the proposed ban given that the individual selected is faculty.
# * Are the events “being a student” and “support the proposed ban” mutually exclusive events? Explain.
# * Are the events “being a student” and “oppose the proposed ban” independent events? Determine the answer by showing the appropriate math work.

# %% [markdown]
# #### Question 2
# In analyzing the sales of the last 200 dress shirts sold at a large men’s wear retail outlet, the manager created the following frequency table.
# ![image.png](attachment:image.png)
# When the next customer walks in to buy a dress shirt, find the probability that:
# * The customer will buy a large dress shirt.
# * The customer will not buy a small dress shirt.
# * What type (concept) of probability are you using in determining your answer to part a above? Briefly explain.

# %% [markdown]
# #### Question 3
# The owner of Jobs-for-All, a privately run job readiness program, publicly claims that anyone who has successfully completed this program will have a 90% chance of finding full-time employment within a month after graduating. To investigate the owner’s claim, a consumer protection agency contacted three people, at random, who had successfully completed Jobs-for-All. The agency was careful to ensure that these three people were contacted one month after graduating from the program. Assuming that the owner’s claim is accurate, compute the following probabilities.
# * What is the probability that all three people contacted obtained full-time jobs?
# * What is the probability that none of the three people contacted obtained full-time jobs.
# * What is the probability that at least one of the three people contacted obtained full-time work?
