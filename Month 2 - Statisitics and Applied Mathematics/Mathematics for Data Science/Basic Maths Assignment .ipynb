# %% [markdown]
# ### Assignment
# 1. Is the value 62.6738 rational or irrational? Why or why not?
# 2. Evaluate the expression: 10710−5
# 3. Evaluate the expression: 81
# 4. Evaluate the expression: 25
# 5. Assuming no payments are made, how much would a $1,000 loan be worth at 5% interest compounded monthly after 3 years? 1 2 3 2
# 6. For the function f (x) = 3x2 + 1 what is the slope at x = 3?
# 7. For the function f (x) = 3x2 + 1 what is the area under the curve for x between 0 and 2?

# %% [raw]
# #1. 62.6738 is rational number, because it can be expressed as a ratio.

# %%
from sympy import *

# %%
# 2
x = 10710
y = 5

print(x-y)
# Out:
# 10705

# %%
# 3 Evaluate the expression: 81

9**2
# Out:
# 81

# %%
# 4 Evaluate the expression: 25

5**2
# Out:
# 25

# %%
# 5 Assuming no payments are made, how much would a $1,000 loan be worth at 5% interest compounded monthly after 3 years? 1 2 3 2

p = 1000
r = .05
t = 3.0
n = 36
x = p * (1 + (r/n))**(n * t)
print(x)
# Out:
# 1161.7133365625095

# %%
# 6 For the function f (x) = 3x2 + 1 what is the slope at x = 3?
import numpy as np
from sympy import *

x = symbols('x')
y = 2*(x**2) + 1
plot(y)

# %%
# 6 For the function f (x) = 3x2 + 1 what is the slope at x = 3?
def slope(y):
    y = 3*(x**2)+1
    return y

print(slope(3))
# Out:
# 28

# %%
# 7 For the function f (x) = 3x2 + 1 what is the area under the curve for x between 0 and 2?
def area(x1, x2):
    y = 3*(x**2)+1
    return y

print(area(0, 2))
# Out:
# 28
